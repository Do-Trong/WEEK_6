# %% [markdown]
# # Derivative and Application
# Tính đạo hàm rời rạc

# %%
import numpy as np
# giảm sử cho một mảng arr
arr = np.array([3, 34, 435, 23, 56, 565, 3, 43, 644])
print(arr)
# Out:
# [  3  34 435  23  56 565   3  43 644]

# %% [markdown]
# Đạo hàm tại x:
# ![image.png](attachment:image.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Tính đạo hàm theo hướng
# ![image.png](attachment:image.png)

# %%
import cv2
from matplotlib import pyplot as plt
img = cv2.imread("image_1.jpg",0)
img = cv2.resize(img,(400,400))
cv2.imshow("image",img)

#compute sobel - x
X = cv2.Sobel(img, cv2.CV_64F, 1, 0)

#compute sobel - y
Y = cv2.Sobel(img, cv2.CV_64F, 0, 1)

cv2.imshow("X",X)
cv2.imshow("Y",Y)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# Khi đó nó sẽ làm nổi bật nên đường theo phương tương ứng
# ![image.png](attachment:image.png)
